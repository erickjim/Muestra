# %%
import pandas as pd
import os 
import numpy as np

# %% [markdown]
# ## Concateación de líneas portadas

# %%
a=[]
for i in os.listdir(r'C:\Users\VDMG015\Documents\Programa Lealtad\Porta'):
    a.append(pd.read_csv('Porta/'+i,sep='\t'))

# %%
df=pd.concat(a)

# %%
df.to_csv('Portadas.csv',index=False)

# %% [markdown]
# Una vez exportado el archivo se extrae la información de las líneas en DbVisualizer

# %%
usr=pd.read_csv('Usuarios.csv',sep='\t')

# %%
usr=usr[['linea','mesproceso','tiposuscripcion','descestatuslinea','antiglinea']]

# %%
usr
# Out:
#              linea  mesproceso tiposuscripcion descestatuslinea antiglinea
# 0       6675824532      202108         PREPAGO           ACTIVO          3
# 1       8712122723      202108         PREPAGO           ACTIVO          3
# 2       7443765457      202108         PREPAGO           ACTIVO          2
# 3       7471064680      202108         PREPAGO           ACTIVO          2
# 4       6391241907      202108         PREPAGO           ACTIVO          2
# ...            ...         ...             ...              ...        ...
# 198449  7838393167      202002         PREPAGO   ZERO BALANCE 1         15
# 198450  5549327925      202002         PREPAGO   ZERO BALANCE 1          2
# 198451  5522594058      202002         PREPAGO           ACTIVO         41
# 198452  4774060504      202002         PREPAGO           ACTIVO          7
# 198453  9932328155      202002         PREPAGO           ACTIVO          4
#
# [198454 rows x 5 columns]

# %%
eq=pd.read_csv('Equipos1.csv',sep='\t')

# %%
mt=pd.read_csv('Recargas1.csv',sep='\t')

# %%
mt.columns=['linea', 'mesproceso', 'monto', 'monto_prom', 'monto_min', 'monto_max',
       'recargas']

# %%
df=usr.merge(eq, how='left',on=['linea','mesproceso'])

# %%
df=df.merge(mt, how='left',on=['linea','mesproceso'])

# %%
df[df['monto'].isna()]['descestatuslinea'].value_counts()
# Out:
# ZERO BALANCE 1    33861
# PRE ACTIVO        13888
# ZERO BALANCE 2    12296
# ACTIVO             6913
# Name: descestatuslinea, dtype: int64

# %%
df.isna().sum()/len(df)
# Out:
# linea               0.000000
# mesproceso          0.000000
# tiposuscripcion     0.000000
# descestatuslinea    0.000000
# antiglinea          0.000000
# modeloeq            0.185353
# monto               0.337390
# monto_prom          0.337390
# monto_min           0.337390
# monto_max           0.337390
# recargas            0.337390
# dtype: float64

# %%
df1=pd.read_csv('Portadas.csv')

# %%
df=df.merge(df1,how='left', on=['linea','mesproceso'])

# %%
df[df['region'].notna()]
# Out:
#              linea  mesproceso tiposuscripcion descestatuslinea antiglinea  \
# 29      6633182878      202108         PREPAGO   ZERO BALANCE 1          2
# 30      2211576679      202108         PREPAGO   ZERO BALANCE 1          2
# 33      9623848127      202108         PREPAGO           ACTIVO          1
# 59      9213219451      202108         PREPAGO           ACTIVO          2
# 79      6565979640      202108         PREPAGO   ZERO BALANCE 1          2
# ...            ...         ...             ...              ...        ...
# 198201  5567442818      202005         PREPAGO   ZERO BALANCE 1         42
# 198208  5548645453      202005         PREPAGO   ZERO BALANCE 1         33
# 198213  2741554433      202005         PREPAGO   ZERO BALANCE 1          4
# 198218  6442447552      202005         PREPAGO   ZERO BALANCE 1          7
# 198244  4614020128      202005         PREPAGO   ZERO BALANCE 1          6
#
# ...

# %%
df1.columns=['linea', 'region', 'mesproceso']

# %%
df[df['linea']==3314530247].sort_values(by='mesproceso')
# Out:
#              linea  mesproceso tiposuscripcion descestatuslinea antiglinea  \
# 73854   3314530247      202002         PREPAGO   ZERO BALANCE 1          2
# 138448  3314530247      202003         PREPAGO   ZERO BALANCE 1          3
# 27868   3314530247      202004         PREPAGO           ACTIVO          4
# 77617   3314530247      202007         PREPAGO           ACTIVO          1
# 39936   3314530247      202008         PREPAGO           ACTIVO          2
# 64745   3314530247      202009         PREPAGO   ZERO BALANCE 1          3
# 5416    3314530247      202010         PREPAGO   ZERO BALANCE 1          4
# 174397  3314530247      202011         PREPAGO           ACTIVO          5
# 177525  3314530247      202012         PREPAGO   ZERO BALANCE 1          6
# 39135   3314530247      202101         PREPAGO   ZERO BALANCE 1          7
# 113893  3314530247      202102         PREPAGO   ZERO BALANCE 1          8
# ...

# %%
'mesproceso'
# Out:
# 'mesproceso'

# %%
df1[df1['mesproceso']==202005]['linea']
# Out:
# 0      8715517941
# 1      6677469784
# 2      6562812546
# 3      2291837642
# 4      8714386487
#           ...
# 995    2721526097
# 996    4492678074
# 997    4431740481
# 998    3321507750
# 999    4611449868
# Name: linea, Length: 1000, dtype: int64

# %%
df=df[~df['linea'].isin(df1[df1['mesproceso']==202005]['linea'])]

# %%
df.sort_values(by='mesproceso',inplace=True)
# Out:
# <ipython-input-163-2476f8c00da7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by='mesproceso',inplace=True)

# %%
df
# Out:
#              linea  mesproceso tiposuscripcion descestatuslinea antiglinea  \
# 198457  4774060504      202002         PREPAGO           ACTIVO          7
# 143763  8129056972      202002         PREPAGO   ZERO BALANCE 1         22
# 143762  2299112160      202002         PREPAGO           ACTIVO        129
# 143761  3111414068      202002         PREPAGO           ACTIVO          4
# 143760  9931678191      202002         PREPAGO           ACTIVO         16
# ...            ...         ...             ...              ...        ...
# 79398   5551906768      202109         PREPAGO   ZERO BALANCE 1          6
# 79397   9933252707      202109         PREPAGO           ACTIVO          1
# 79396   2711601273      202109         PREPAGO           ACTIVO          0
# 79394   9911133195      202109         PREPAGO           ACTIVO         11
# 156080  2292645268      202109         PREPAGO           ACTIVO          2
#
# ...

# %%
aux=df.drop_duplicates('linea',keep='last' )

# %%
aux['antiglinea']=aux['antiglinea'].replace('(null)','')
# Out:
# <ipython-input-295-a4f7c5fa4d96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aux['antiglinea']=aux['antiglinea'].replace('(null)','')

# %%
aux['antiglinea']=aux['antiglinea'].replace('',0)
# Out:
# <ipython-input-298-471ffca74902>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aux['antiglinea']=aux['antiglinea'].replace('',0)

# %%
aux['antiglinea'].astype(int)
# Out:
# 97749      77
# 198304     16
# 43853     176
# 43865       2
# 128026     48
#          ...
# 79398       6
# 79397       1
# 79396       0
# 79394      11
# 156080      2
# Name: antiglinea, Length: 15756, dtype: int32

# %%
aux['antiglinea']=aux['antiglinea'].astype(float)
# Out:
# <ipython-input-306-cd618fab3213>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aux['antiglinea']=aux['antiglinea'].astype(float)

# %%
aux['antiglinea'].describe(percentiles=[.1,.25,.5,.75,.95])
# Out:
# count    15756.000000
# mean        13.561056
# std         21.949095
# min          0.000000
# 10%          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%         14.000000
# 95%         53.000000
# max        214.000000
# Name: antiglinea, dtype: float64

# %%
df1
# Out:
#             linea region  mesproceso
# 0      8715517941    R03      202005
# 1      6677469784    R02      202005
# 2      6562812546    R03      202005
# 3      2291837642    R07      202005
# 4      8714386487    R03      202005
# ...           ...    ...         ...
# 16995  5534234920    R09      202109
# 16996  2712140256    R07      202109
# 16997  4448622904    R06      202109
# 16998  4651545610    R06      202109
# 16999  6141282652    R03      202109
#
# [17000 rows x 3 columns]

# %%
df[(df['linea']==2712140256)]
# Out:
#              linea  mesproceso tiposuscripcion descestatuslinea antiglinea  \
# 181361  2712140256      202009         PREPAGO   ZERO BALANCE 1          1
# 149663  2712140256      202010         PREPAGO   ZERO BALANCE 1          2
# 63465   2712140256      202011         PREPAGO   ZERO BALANCE 1          3
# 192650  2712140256      202012         PREPAGO           ACTIVO          4
# 55711   2712140256      202101         PREPAGO           ACTIVO          5
# 34246   2712140256      202102         PREPAGO           ACTIVO          6
# 112374  2712140256      202103         PREPAGO           ACTIVO          7
# 132413  2712140256      202104         PREPAGO           ACTIVO          8
# 181100  2712140256      202105         PREPAGO   ZERO BALANCE 1          9
# 77031   2712140256      202106         PREPAGO           ACTIVO         10
# 8713    2712140256      202107         PREPAGO           ACTIVO         11
# ...

# %%
df[df['linea']==df['linea'].sample().values[0]]
# Out:
#              linea  mesproceso tiposuscripcion descestatuslinea antiglinea  \
# 63910   9982192224      202002         PREPAGO       PRE ACTIVO     (null)
# 184458  9982192224      202003         PREPAGO       PRE ACTIVO     (null)
# 107567  9982192224      202004         PREPAGO           ACTIVO          0
# 55031   9982192224      202005         PREPAGO           ACTIVO          1
# 43937   9982192224      202006         PREPAGO           ACTIVO          2
# 121511  9982192224      202007         PREPAGO           ACTIVO          3
# 173814  9982192224      202008         PREPAGO           ACTIVO          4
# 80514   9982192224      202009         PREPAGO           ACTIVO          5
# 123413  9982192224      202010         PREPAGO           ACTIVO          6
# 77784   9982192224      202011         PREPAGO           ACTIVO          8
# 115238  9982192224      202012         PREPAGO           ACTIVO          9
# ...

# %%
a=[]
for i in df1['mesproceso'].unique():
    b=df[(df['mesproceso']<i)&(df['linea'].isin(df1[df1['mesproceso']==i]['linea']))]
    a.append(b)

# %%
df2=pd.concat(a)

# %%
df2[df2['linea']==df2['linea'].sample().values[0]]
# Out:
#              linea  mesproceso tiposuscripcion descestatuslinea antiglinea  \
# 42228   7225553204      202002         PREPAGO           ACTIVO          5
# 101831  7225553204      202003         PREPAGO           ACTIVO          6
# 25335   7225553204      202004         PREPAGO   ZERO BALANCE 1          7
# 135436  7225553204      202005         PREPAGO           ACTIVO          8
# 124039  7225553204      202006         PREPAGO           ACTIVO          9
# 92162   7225553204      202007         PREPAGO           ACTIVO         10
# 132732  7225553204      202008         PREPAGO           ACTIVO         11
# 108999  7225553204      202009         PREPAGO   ZERO BALANCE 1         12
# 160062  7225553204      202010         PREPAGO           ACTIVO         13
# 88515   7225553204      202011         PREPAGO           ACTIVO         14
# 164158  7225553204      202012         PREPAGO   ZERO BALANCE 1         15
# ...

# %%
df2.isna().sum()/len(df2)
# Out:
# linea               0.000000
# mesproceso          0.000000
# tiposuscripcion     0.000000
# descestatuslinea    0.000000
# antiglinea          0.000000
# modeloeq            0.187403
# monto               0.334935
# monto_prom          0.334935
# monto_min           0.334935
# monto_max           0.334935
# recargas            0.334935
# region              0.999971
# dtype: float64

# %%
df2=df2[df2['descestatuslinea']!='PRE ACTIVO']

# %%
df2.drop('region',axis=1,inplace=True)
# Out:
# C:\Users\VDMG015\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df2=df2[df2['descestatuslinea']!='ZERO BALANCE 2']

# %%
df2['modeloeq']=df2['modeloeq'].replace('(null)',np.nan)
# Out:
# <ipython-input-470-e142009fb8c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['modeloeq']=df2['modeloeq'].replace('(null)',np.nan)

# %%
df2['modeloeq'].replace('(null)',np.nan)
# Out:
# 143785                     ILIUM X220
# 143769                       1V 5001A
# 143714           GALAXY J1 2016 J120A
# 68939                           E450F
# 68927                   MOTO C XT1756
#                      ...
# 21438                    ONE XT1941-5
# 21356                             NaN
# 21454                           AX687
# 21451     GALAXY GRAND PRIME VE G531H
# 21448               GALAXY A70 A705MN
# Name: modeloeq, Length: 119098, dtype: object

# %%
df2['antiglinea']=df2['antiglinea'].astype(int)
# Out:
# <ipython-input-476-4e3b133e3f49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['antiglinea']=df2['antiglinea'].astype(int)

# %%
import pickle

# %%
df2.to_pickle('prep_hist.pkl')
